# %% [markdown]
# # **Connecting to Dataset on Drive**

# %%
from google.colab import drive
import shutil
import os
import sys

drive.mount('/content/drive')
#Copy of data and code
#Copy Data
drive_data = '/content/drive/My Drive/aesthetics_project'
colab_data = '/content/data'
if os.path.exists(drive_data):
    shutil.copytree(drive_data, colab_data, dirs_exist_ok=True)
    print("Copied data from Drive")

#Copy Source Code
drive_src = '/content/drive/My Drive/src'
colab_src = '/content/src'
if os.path.exists(drive_src):
    shutil.copytree(drive_src, colab_src, dirs_exist_ok=True)
    print("Copied src code from Drive")

#Added to Python Path
if '/content/src' not in sys.path:
    sys.path.append('/content/src')
    print("Added /content/src to Python path")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Copied data from Drive
# Copied src code from Drive

# %% [markdown]
# # **Installing StyloMetrix and spaCy**

# %%
print("Installing StyloMetrix and spaCy models...")
# !pip install stylo-metrix
# !pip install spacy-transformers
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3.tar.gz
print("Installation complete!")
# Out:
# Installing StyloMetrix and spaCy models...
# Requirement already satisfied: stylo-metrix in /usr/local/lib/python3.12/dist-packages (0.1.9.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (0.4.6)
# Requirement already satisfied: confection in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (0.1.5)
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (2.15.0)
# Requirement already satisfied: morfeusz2 in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (1.99.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (1.16.3)
# Requirement already satisfied: spacy==3.7.2 in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (3.7.2)
# Requirement already satisfied: spacymoji in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (3.1.0)
# Requirement already satisfied: srsly in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (2.5.2)
# Requirement already satisfied: thinc in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (8.2.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (4.67.3)
# Requirement already satisfied: spacy-syllables in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (3.0.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.12/dist-packages (from stylo-metrix) (4.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (26.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.2->stylo-metrix) (3.5.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.12/dist-packages (from thinc->stylo-metrix) (0.7.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->stylo-metrix) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stylo-metrix) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stylo-metrix) (2025.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect->stylo-metrix) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->stylo-metrix) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->stylo-metrix) (3.6.0)
# Requirement already satisfied: pyphen>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from spacy-syllables->stylo-metrix) (0.17.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->stylo-metrix) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->stylo-metrix) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->stylo-metrix) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->stylo-metrix) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->stylo-metrix) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->stylo-metrix) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->stylo-metrix) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->stylo-metrix) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->stylo-metrix) (2026.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.3.0->spacy==3.7.2->stylo-metrix) (8.3.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.2->stylo-metrix) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy==3.7.2->stylo-metrix) (3.0.3)
# Collecting spacy-transformers
#   Using cached spacy_transformers-1.3.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from spacy-transformers) (3.7.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy-transformers) (1.26.4)
# Collecting transformers<4.50.0,>=3.4.0 (from spacy-transformers)
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from spacy-transformers) (2.10.0+cpu)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from spacy-transformers) (2.5.2)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers)
#   Using cached spacy_alignments-0.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (26.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy-transformers) (3.24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy-transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy-transformers) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->spacy-transformers) (2025.3.0)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers<4.50.0,>=3.4.0->spacy-transformers)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (2025.11.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.50.0,>=3.4.0->spacy-transformers)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers<4.50.0,>=3.4.0->spacy-transformers) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.3.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.3)
# Downloading spacy_transformers-1.3.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (795 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 24.5 MB/s eta 0:00:00
# Downloading spacy_alignments-0.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 16.8 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 88.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 30.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.2 MB/s eta 0:00:00
# Installing collected packages: spacy-alignments, huggingface-hub, tokenizers, transformers, spacy-transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.50.0 requires typer<1.0,>=0.12, but you have typer 0.9.4 which is incompatible.
# Successfully installed huggingface-hub-0.36.2 spacy-alignments-0.9.2 spacy-transformers-1.3.9 tokenizers-0.21.4 transformers-4.49.0
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3.tar.gz (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.12/dist-packages (from en_core_web_trf==3.7.3) (3.7.2)
# Collecting spacy-curated-transformers<0.3.0,>=0.2.0 (from en_core_web_trf==3.7.3)
#   Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (26.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.5.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (1.26.4)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3)
#   Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (2.10.0+cpu)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.12/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (2025.11.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (2026.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (3.24.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (2025.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (8.3.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en_core_web_trf==3.7.3) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en_core_web_trf==3.7.3) (1.3.0)
# Downloading spacy_curated_transformers-0.2.2-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 13.0 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 32.3 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Building wheels for collected packages: en_core_web_trf
#   Building wheel for en_core_web_trf (setup.py) ... done
#   Created wheel for en_core_web_trf: filename=en_core_web_trf-3.7.3-py3-none-any.whl size=457413481 sha256=883afd402ca6ea3e17b98edbb16e7a47b16e0ca0a062035defd2c56f9cdcdd2f
#   Stored in directory: /root/.cache/pip/wheels/d7/95/86/4423b3e9fd8581cdcbc6023f5ded42e622b710dd0f7328d8f6
# Successfully built en_core_web_trf
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en_core_web_trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en_core_web_trf-3.7.3 spacy-curated-transformers-0.2.2
# Installation complete!

# %%
#Setup
import pandas as pd
import sys
sys.path.append('/content/src')

# %% [markdown]
# # **Extracting Features with StyloMetrix**

# %%
from feature_extraction.stylometrix_wrapper import StyloMetrixExtractor

print("Running StyloMetrix feature extraction...")

# Initializing custom OOP wrapper
extractor = StyloMetrixExtractor(lang='en')

# Running the extraction
features_df = extractor.extract(
    input_folder='/content/data/raw',
    output_csv='/content/data/features.csv'
)

print("Feature extraction complete!")
# Out:
# Running StyloMetrix feature extraction...
# Initializing StyloMetrix for language 'en'...
# Extracting features for 320 documents. This might take a minute...
#   0%|          | 0/320 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 100%|██████████| 320/320 [08:06<00:00,  1.52s/it]
# Feature extraction complete!

# %%
# Verification that features were extracted
if os.path.exists('/content/data/features.csv'):
    features_df = pd.read_csv('/content/data/features.csv')
    print(f"Features extracted! Shape: {features_df.shape}")
    print(f"Number of stylometric features: {features_df.shape[1] - 1}")

    # Check of first 5 rows of features
    print("\nFeatures preview:")
    print(features_df.head())
else:
    print("Feature extraction failed")
    sys.exit(1)
# Out:
# Features extracted! Shape: (320, 198)
# Number of stylometric features: 197
#
# Features preview:
#                     doc_id                                               text  \
# 0      GPT_description_067  As the sun begins its descent toward the horiz...
# 1     Claude_narration_168  # The First Stroke\n\nUnit Seven had been assi...
# 2         GPT_dialogue_055  **Title: A Walk in the Park**\n\n**Characters:...
# 3        GPT_narration_001  In the quiet town of Verdant Grove, where the ...
# 4  LLaMA_argumentation_103  **Argument For the Use of AI in Creative Writi...
#
#    POS_VERB  POS_NOUN   POS_ADJ   POS_ADV   POS_DET  POS_INTJ  POS_CONJ  \
# 0  0.165644  0.288344  0.092025  0.049080  0.184049  0.000000  0.042945
# 1  0.212329  0.239726  0.061644  0.020548  0.095890  0.006849  0.034247
# 2  0.174497  0.194631  0.114094  0.046980  0.100671  0.006711  0.060403
# 3  0.221519  0.208861  0.082278  0.012658  0.126582  0.000000  0.056962
# 4  0.171975  0.318471  0.133758  0.038217  0.050955  0.000000  0.044586
#
#    POS_PART  ...   RE  ASF       ASM        OM  RCI       DMC        OR  \
# 0  0.006135  ...  0.0  0.0  0.000000  0.000000  0.0  0.006135  0.000000
# 1  0.006849  ...  0.0  0.0  0.000000  0.000000  0.0  0.006849  0.000000
# 2  0.006711  ...  0.0  0.0  0.006711  0.020134  0.0  0.000000  0.000000
# 3  0.031646  ...  0.0  0.0  0.006329  0.000000  0.0  0.006329  0.006329
# 4  0.025478  ...  0.0  0.0  0.019108  0.031847  0.0  0.000000  0.000000
#
#         QAS        PA   PR
# 0  0.128834  0.000000  0.0
# 1  0.082192  0.000000  0.0
# 2  0.026846  0.000000  0.0
# 3  0.082278  0.006329  0.0
# 4  0.057325  0.000000  0.0
#
# [5 rows x 198 columns]

# %% [markdown]
# # **Merging with the Metadata**

# %%
import os
import sys
import shutil
import importlib
import pandas as pd

#Due to ghost folder problem, I forced Colab to pull the fresh, updated file from the Drive right before it merges.
drive_file = '/content/drive/My Drive/src/feature_extraction/preprocess.py'
local_file = '/content/src/feature_extraction/preprocess.py'

if os.path.exists(drive_file):
    shutil.copy2(drive_file, local_file)
    print("Pulled updated preprocess.py from Drive")

#Reloading the module so Python sees the new code
import feature_extraction.preprocess
importlib.reload(feature_extraction.preprocess)
from feature_extraction.preprocess import merge_features

print("Merging features with metadata...")

metadata_path = '/content/data/metadata.csv'
features_path = '/content/data/features.csv'

if os.path.exists(metadata_path):
    merged = merge_features(metadata_path, features_path)
    print(f"Merged successfully! Shape: {merged.shape}")

    #Safety: If it's still 0, show us EXACTLY why
    if merged.shape[0] == 0:
        print("\nDEBUG: The IDs still don't match. Let's look at them:")
        meta_df = pd.read_csv(metadata_path)
        feat_df = pd.read_csv(features_path)

        # Check if doc_id exists in metadata
        if 'doc_id' in meta_df.columns:
            print(f"Metadata IDs look like this : {meta_df['doc_id'].head(3).tolist()}")
        else:
            print(f"Metadata columns are        : {meta_df.columns.tolist()}")

        print(f"Feature IDs look like this  : {feat_df['doc_id'].head(3).tolist()}")
else:
    print("metadata.csv not found!")
    sys.exit(1)
# Out:
# Pulled updated preprocess.py from Drive
# Merging features with metadata...
# Merged successfully! Shape: (320, 201)

# %% [markdown]
# # **Saving the Dataset**

# %%
merged.to_csv('/content/data/merged_features.csv', index=False)
print("Dataset saved to /content/data/merged_features.csv")
# Out:
# Dataset saved to /content/data/merged_features.csv

# %% [markdown]
# # **Quick Overview**

# %%
#Quick exploration
print("\n=== Dataset Overview ===")
print(f"Total documents: {len(merged)}")
print(f"Models: {merged['model'].unique()}")
print(f"Genres: {merged['genre'].unique()}")
# Out:
# === Dataset Overview ===
# Total documents: 320
# Models: ['GPT' 'LLaMA' 'Claude' 'Mistral']
# Genres: ['narration' 'argumentation' 'dialogue' 'description']

# %%
#Show feature columns (excluding metadata)
metadata_cols = ['doc_id', 'model', 'genre', 'prompt']
feature_cols = [col for col in merged.columns if col not in metadata_cols]
print(f"\nNumber of stylometric features: {len(feature_cols)}")
print(f"Sample features: {feature_cols[:10]}")
# Out:
# Number of stylometric features: 197
# Sample features: ['text', 'POS_VERB', 'POS_NOUN', 'POS_ADJ', 'POS_ADV', 'POS_DET', 'POS_INTJ', 'POS_CONJ', 'POS_PART', 'POS_NUM']

# %%
#Basic statistics
print("\n=== Documents per model ===")
print(merged['model'].value_counts())

print("\n=== Documents per genre ===")
print(merged['genre'].value_counts())
# Out:
# === Documents per model ===
# model
# GPT        80
# LLaMA      80
# Claude     80
# Mistral    80
# Name: count, dtype: int64
#
# === Documents per genre ===
# genre
# narration        80
# argumentation    80
# dialogue         80
# description      80
# Name: count, dtype: int64

# %%
# Preview of the merged data
print("\n=== First 5 rows of merged data ===")
merged.head()
# Out:
# === First 5 rows of merged data ===
#               doc_id model      genre  \
# 0  GPT_narration_000   GPT  narration
# 1  GPT_narration_001   GPT  narration
# 2  GPT_narration_002   GPT  narration
# 3  GPT_narration_003   GPT  narration
# 4  GPT_narration_004   GPT  narration
#
#                                               prompt  \
# 0  Write a short story about a robot learning to ...
# 1  Write a short story about a robot learning to ...
# 2  Write a short story about a robot learning to ...
# 3  Write a short story about a robot learning to ...
# 4  Write a short story about a robot learning to ...
#
#                                                 text  POS_VERB  POS_NOUN  \
# 0  In a small workshop at the edge of a bustling ...  0.201220  0.256098
# 1  In the quiet town of Verdant Grove, where the ...  0.221519  0.208861
# 2  In a small workshop filled with the scent of o...  0.163399  0.261438
# 3  In a quiet workshop on the outskirts of a bust...  0.208589  0.239264
# 4  In a small workshop at the edge of a bustling ...  0.229299  0.254777
#
#     POS_ADJ   POS_ADV   POS_DET  ...   RE  ASF       ASM        OM  RCI  \
# 0  0.091463  0.024390  0.134146  ...  0.0  0.0  0.006098  0.000000  0.0
# 1  0.082278  0.012658  0.126582  ...  0.0  0.0  0.006329  0.000000  0.0
# 2  0.111111  0.019608  0.124183  ...  0.0  0.0  0.000000  0.000000  0.0
# 3  0.079755  0.024540  0.122699  ...  0.0  0.0  0.006135  0.000000  0.0
# 4  0.057325  0.019108  0.095541  ...  0.0  0.0  0.006369  0.019108  0.0
#
#         DMC        OR       QAS        PA   PR
# 0  0.000000  0.000000  0.097561  0.000000  0.0
# 1  0.006329  0.006329  0.082278  0.006329  0.0
# 2  0.006536  0.000000  0.078431  0.000000  0.0
# 3  0.000000  0.000000  0.049080  0.000000  0.0
# 4  0.000000  0.000000  0.057325  0.000000  0.0
#
# [5 rows x 201 columns]

# %% [markdown]
# # **Saving results to Drive**

# %%
print("\nSaving results back to Drive...")
#saving merged features
merged.to_csv('/content/drive/My Drive/aesthetics_project/merged_features.csv', index=False)

#copy of for backup
# !cp /content/data/features.csv "/content/drive/My Drive/aesthetics_project/features.csv"

print("All files saved to Drive:")
print("   - aesthetics_project/merged_features.csv")
print("   - aesthetics_project/features.csv")
print("   - aesthetics_project/results/ (will contain future plots)")
# Out:
# Saving results back to Drive...
# All files saved to Drive:
#    - aesthetics_project/merged_features.csv
#    - aesthetics_project/features.csv
#    - aesthetics_project/results/ (will contain future plots)
